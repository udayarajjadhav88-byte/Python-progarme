# %%
a = 10 
b = 4  

print(f"AND: {a & b}")   
print(f"OR:  {a | b}")   
print(f"XOR: {a ^ b}")   
print(f"NOT: {~a}")    
print(f"Left Shift (a << 1): {a << 1}")   
print(f"Right Shift (a >> 1): {a >> 1}")
# Out:
# AND: 0
# OR:  14
# XOR: 14
# NOT: -11
# Left Shift (a << 1): 20
# Right Shift (a >> 1): 5
