# %%
a=15
b=10

print("a==b:",a==b)
print("a!=b:",a!=b)
print("a>b:",a>b)
print("a<b:",a<b)
print("a>=b:",a>=b)
print("a<=b:",a<=b)
if a>b:
    print("a is greater then b")
else:
    print("a is not greater then b")
# Out:
# a==b: False
# a!=b: True
# a>b: True
# a<b: False
# a>=b: True
# a<=b: False
# a is greater then b
