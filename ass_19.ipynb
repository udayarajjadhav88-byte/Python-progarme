# %%
students=["uday","somu","arun"]
print(students)

print(students[0])
print(students[-1])
print(students[-3:-1])

students.append("Rakshita")
students.insert(1,"Shankar")
students.remove("Rakshita")

print(students)

students.sort()
print(students)
students.reverse()
print(students)
len(students)
# Out:
# ['uday', 'somu', 'arun']
# uday
# arun
# ['uday', 'somu']
# ['uday', 'Shankar', 'somu', 'arun']
# ['Shankar', 'arun', 'somu', 'uday']
# ['uday', 'somu', 'arun', 'Shankar']
# 4
