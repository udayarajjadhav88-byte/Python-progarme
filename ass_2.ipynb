# %%
fruits = ["apple", "banana", "cherry"]
message = "Hello World"
user_scores = {"Alice": 95, "Bob": 88}


print("banana" in fruits)     
print("W" in message)        
print("Alice" in user_scores)  


print("orange" not in fruits)  
print("Z" not in message)      
print(95 not in user_scores)
