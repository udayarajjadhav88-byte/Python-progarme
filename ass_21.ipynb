# %%
employees={
    1001:"Ramesh",1002:"Suresh",1003:"Rajesh"
}
print(employees)
print(employees[1002])
print(employees.keys())
print(employees.values())
employees[1005]="Radhika"
employees[1001]='Rakesh'
employees[1005]='Rakesh'
print(employees)
len(employees)
# Out:
# {1001: 'Ramesh', 1002: 'Suresh', 1003: 'Rajesh'}
# Suresh
# dict_keys([1001, 1002, 1003])
# dict_values(['Ramesh', 'Suresh', 'Rajesh'])
# {1001: 'Rakesh', 1002: 'Suresh', 1003: 'Rajesh', 1005: 'Rakesh'}
# 4
