# %%
def eligible(age,percentage):
    if age>=18:
        if percantage>=60:
            print("student is eligibal for addmition:")
    else:
        print("student is not eligibal for addmition:")
age = int(input("enter age:"))
percantage=float(input("enter percntage:"))
ads=eligible(age,percantage)
# Out:
# enter age: 20
# enter percntage: 95
# student is eligibal for addmition:
